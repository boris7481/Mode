# %% [markdown]
# 1. Pyplot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Graphiques simples

# %%
X = np.linspace(0, 2, 10)
y = X**2

plt.plot(X, y)
plt.show()

# %%
plt.scatter(X, y)
plt.show()

# %% [markdown]
# Styles Graphiques
#
# Il existe beaucoup de styles a ajouter aux graphiques. Voici les plus importants a retenir :
#
#     c : couleur de la ligne
#     lw : epaisseur de la ligne (pour les graphiques plot)
#     ls : style de la ligne (pour les graphiques plot)
#     size : taille du point (pour les graphiques scatter)
#     marker : style de points (pour les graphiques scatter)
#     alpha : transparence du graphiqu

# %%
plt.plot(X, y, c='red', lw=4, ls='--', alpha=0.8)
plt.show()

# %% [markdown]
# 2. Cycle de vie d'une figure
#
# Pour créer des figures proprements, on doit suivre le cycle de vie suivant :
#
#     plt.figure(figsize())
#     plt.plot()
#     Extras (titre, axes, legendes)
#     plt.show()

# %%
X = np.linspace(0, 2, 10)

plt.figure() # Création d'une figure
plt.plot(X, X**2, label='quadratique') # premiere courbe
plt.plot(X, X**3, label='cubique') # deuxieme courbe
# Extra information
plt.title('figure 1') # titre
plt.xlabel('axe x') # axes
plt.ylabel('axe y') # axes
plt.legend() # legend

plt.savefig('figure.png') # sauvegarde la figure dans le repertoire de travail
plt.show() # affiche la figure

# %% [markdown]
# 3. Subplots
#
# Les subplots sont un autre éléments a ajouter pour créer plusieurs graphiques sur une meme figure

# %%
X = np.linspace(0, 2, 10)

plt.subplot(2, 1, 1)
plt.plot(X, y, c='red')
plt.subplot(2, 1, 2)
plt.plot(X, y, c='blue')

# %% [markdown]
# #### 4. Méthode orientée objet

# %%
X = np.linspace(0, 2, 10)

fig, ax = plt.subplots(2, 1, sharex=True) # partage le meme axe pour les subplots
ax[0].plot(X, y)
ax[1].plot(X, np.sin(X))
plt.show()

# %% [markdown]
# 5. Exercice et Solution
#
# Créez une fonction "graphique" qui permet de tracer sur une seule et meme figure une série de graphiques issue d'un dictionnaire contenant plusieurs datasets :

# %%
def graphique(dataset):
  # Votre code ici...
  return

# Voici le dataset utilisé
dataset = {f"experience{i}": np.random.randn(100) for i in range(4)}

dataset
# Out:
# {'experience0': array([-0.74511768,  1.50519176, -0.13625643,  0.14687301,  0.79619942,
#         -0.15169225,  0.46254908, -1.06172582,  0.33485391,  2.57446646,
#         -0.36123773, -0.3183059 ,  1.74080857,  0.71935446,  0.31263188,
#          0.05584541, -0.08599226, -0.79554705, -0.86138037, -2.18468525,
#          1.8728827 ,  2.4502415 , -0.95120842, -1.20454797, -0.93638118,
#          0.64960469, -0.90497732,  1.54647278,  0.58272769, -0.92323758,
#          0.84584067,  1.79523626, -0.92668591, -0.15539097, -0.22795509,
#          0.36588461, -1.17049689, -0.21120878,  0.13056137,  0.67673594,
#          1.18337269,  0.66996177, -1.58043029, -1.28603457, -1.60067268,
#         -0.00746644,  0.66884489,  0.58550897,  0.4263857 ,  0.34857499,
#          0.18099861,  0.85501235, -0.31638186,  0.11415489, -1.1379113 ,
#         -0.06088206, -0.36440073,  1.78055112,  0.35301457,  0.01600747,
#         -0.53626596, -0.5619021 ,  0.94023549,  0.42726489, -0.22318317,
#          0.67449922, -0.34277049,  0.25378218, -0.21548257, -0.02895838,
#         -0.23468668,  1.27464496, -1.63024537, -0.25443188,  0.21952695,
#         -1.82760392,  0.31657705, -1.0619093 , -0.73416706,  1.09011808])}

# %%
# SOLUTION
def graphique(data):
    n = len(data)
    plt.figure(figsize=(12, 20))
    
    for k, i in zip(data.keys(), range(1, n+1)):
        plt.subplot(n, 1, i)
        plt.plot(data[k])
        plt.title(k)
        
    plt.show()

# %%
graphique(dataset)

# %% [markdown]
# ###  Matplotlib Top Graphiques

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ##  1.Graphique de Classification avec Scatter()

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x = iris.data
y = iris.target

print(f'x contient {x.shape[0]} exmples et {x.shape[1]} variables')
print(f'il y a {np.unique(y).size} classes')
# Out:
# x contient 150 exmples et 4 variables
# il y a 3 classes

# %%
n = x.shape[1]
plt.figure(figsize=(12, 8))
for i in range(n):
    plt.subplot(n//2, n//2, i+1)
    plt.scatter(x[:, 0], x[:, i], c=y)
    plt.xlabel('0')
    plt.ylabel(i)
    plt.colorbar(ticks=list(np.unique(y)))
plt.show()

# %% [markdown]
# 2. Graphiques 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection='3d')
ax.scatter(x[:, 0], x[:, 1], x[:,2], c=y)

# %%
f = lambda x, y: np.sin(x) + np.cos(x+y)

X = np.linspace(0, 5, 50)
Y = np.linspace(0, 5, 50)
X, Y = np.meshgrid(X, Y)
Z = f(X, Y)

ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, cmap='plasma')
plt.show()

# %%
x = np.random.randn(1000)

plt.figure(figsize=(12, 3))
plt.subplot(121)
plt.hist(x, bins=10)
plt.title('bins=10')
plt.subplot(122)
plt.hist(x, bins=50)
plt.title('bins= 50')
plt.show()

# %%
# histogramme d'une image
from scipy import misc
face = misc.face(gray=True)

plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.imshow(face, cmap='gray')
plt.subplot(122)
plt.hist(face.ravel(), bins=255)
plt.show()

# %% [markdown]
# 4. Graphiques ContourPlot()

# %%
f = lambda x, y: np.sin(x) + np.cos(x+y)*np.cos(x)

X = np.linspace(0, 5, 50)
Y = np.linspace(0, 5, 50)
X, Y = np.meshgrid(X, Y)
Z = f(X, Y)

plt.contour(X, Y, Z, 20, colors='black')

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# 5. Imshow()

# %%
plt.figure(figsize=(12, 3))

# Simple graphique imshow()
X = np.random.randn(50, 50)

plt.subplot(131)
plt.imshow(X)
plt.title('random normal')

# Matrice de corrélation des iris
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target


plt.subplot(132)
plt.imshow(np.corrcoef(X.T, y))
plt.title('Iris Corrélation')

# Matrice f(X, Y) = sin(X) + cos(Y)
X = np.linspace(0, 5, 100)
Y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(X, Y)

plt.subplot(133)
plt.imshow(f(X, Y))
plt.colorbar()
plt.title('f(x, y) = sin(x) + cos(y)')
# Out:
# Text(0.5, 1.0, 'f(x, y) = sin(x) + cos(y)')
