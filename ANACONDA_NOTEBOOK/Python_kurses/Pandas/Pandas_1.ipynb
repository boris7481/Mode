# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_excel("simple_dataset.xlsx")
# Out:
# C:\Users\boris-thibaut.tondju\Anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")

# %%
data.shape
# Out:
# (9994, 21)

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 1       2  CA-2018-152156 2018-11-08 2018-11-11    Second Class    CG-12520
# 2       3  CA-2018-138688 2018-06-12 2018-06-16    Second Class    DV-13045
# 3       4  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
# 4       5  US-2017-108966 2017-10-11 2017-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country/Region             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
data.describe().transpose()
# Out:
#               count          mean           std       min          25%  \
# Row ID       9994.0   4997.500000   2885.163629     1.000   2499.25000
# Postal Code  9983.0  55245.233297  32038.715955  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Row ID        4997.5000   7495.750   9994.000
# Postal Code  57103.0000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Date       9994 non-null   datetime64[ns]
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data = data.drop(  ["Row ID",'Order ID', 'Order Date'] , axis = 1)

# %%
data.shape
# Out:
# (9994, 18)

# %%
# for col in data.select_dtypes('object'):
#    print(f'{col :-<50} {data[col].unique()}')

# %%
data['Quantity'].hist()
# Out:
# <AxesSubplot:>

# %%
data.groupby(["Quantity"]).mean()
# Out:
#            Postal Code        Sales  Discount      Profit
# Quantity
# 1         53848.426979    59.234632  0.152959    8.276396
# 2         55156.736776   120.354488  0.154858   16.006831
# 3         54965.393851   175.201578  0.153329   23.667715
# 4         54904.040336   271.764059  0.157708   37.131310
# 5         56778.386808   337.936339  0.157146   40.257394
# 6         55138.747811   362.101960  0.166556   18.051517
# 7         55806.828099   395.888393  0.161980   56.579163
# 8         56692.369650   458.210802  0.171595   42.244342
# 9         54736.406977   498.083683  0.147946   68.557716
# 10        55343.105263   422.046737  0.190702   35.862404
# 11        55274.764706   463.896529  0.097059  126.275503
# 12        68679.130435   646.452522  0.113043   51.524609
# 13        45265.730769  1197.710704  0.157407  235.144481
# 14        58231.517241   452.826138  0.151724   93.931166

# %%
data.groupby(['Quantity', 'Sales']).mean()
# Out:
#                    Postal Code  Discount    Profit
# Quantity Sales
# 1        0.444         77095.0       0.8   -1.1100
#          0.556         76706.0       0.8   -0.9452
#          0.836         60623.0       0.8   -1.3376
#          0.852         19120.0       0.7   -0.5964
#          0.876         75150.0       0.8   -1.4016
# ...                        ...       ...       ...
# 14       1075.088      90278.0       0.2   94.0702
#          1119.888      19120.0       0.2  209.9790
#          1336.440      68104.0       0.0  387.5676
#          1702.120      94122.0       0.0  510.6360
#          1819.860      35630.0       0.0  163.7874
#
# [6659 rows x 3 columns]

# %%
data["Region"].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
data[data["Region"] == "west"]
# Out:
# Empty DataFrame
# Columns: [Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country/Region, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []

# %%
data[data['Sales'] < 10008]['Region'].value_counts()
# Out:
# West       3202
# East       2846
# Central    2322
# South      1619
# Name: Region, dtype: int64

# %% [markdown]
# ## Making changes to the data

# %%
# df['Total'] = df.iloc[:, 4:10].sum(axis=1)

# cols = list(df.columns)
# df = df[cols[0:4] + [cols[-1]]+cols[4:12]]

# df.head(5)

# %% [markdown]
# ### Saving our Data (Exporting into Desired Format)

# %%
# df.to_csv('modified.csv', index=False)

#df.to_excel('modified.xlsx', index=False)

# df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# ### Filtering Data

# %%
# new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]

# new_df.reset_index(drop=True, inplace=True)

# new_df

# new_df.to_csv('filtered.csv')

# %%
data["Region"]
# Out:
# 0       South
# 1       South
# 2        West
# 3       South
# 4       South
#         ...
# 9989    South
# 9990     West
# 9991     West
# 9992     West
# 9993     West
# Name: Region, Length: 9994, dtype: object

# %%
type(data["Region"])
# Out:
# pandas.core.series.Series

# %%
data[["Region" , "Sales"]]
# Out:
#      Region     Sales
# 0     South  261.9600
# 1     South  731.9400
# 2      West   14.6200
# 3     South  957.5775
# 4     South   22.3680
# ...     ...       ...
# 9989  South   25.2480
# 9990   West   91.9600
# 9991   West  258.5760
# 9992   West   29.6000
# 9993   West  243.1600
#
# [9994 rows x 2 columns]

# %%
data.iloc[0] # give the first row iloc = Integer location only work with integer
# Out:
# Ship Date                       2018-11-11 00:00:00
# Ship Mode                              Second Class
# Customer ID                                CG-12520
# Customer Name                           Claire Gute
# Segment                                    Consumer
# Country/Region                        United States
# City                                      Henderson
# State                                      Kentucky
# Postal Code                                 42420.0
# Region                                        South
# Product ID                          FUR-BO-10001798
# Category                                  Furniture
# Sub-Category                              Bookcases
# Product Name      Bush Somerset Collection Bookcase
# Sales                                        261.96
# Quantity                                          2
# Discount                                        0.0
# Profit                                      41.9136
# Name: 0, dtype: object

# %%
data.iloc[[0 , 1]]
# Out:
#    Ship Date     Ship Mode Customer ID Customer Name   Segment Country/Region  \
# 0 2018-11-11  Second Class    CG-12520   Claire Gute  Consumer  United States
# 1 2018-11-11  Second Class    CG-12520   Claire Gute  Consumer  United States
#
#         City     State  Postal Code Region       Product ID   Category  \
# 0  Henderson  Kentucky      42420.0  South  FUR-BO-10001798  Furniture
# 1  Henderson  Kentucky      42420.0  South  FUR-CH-10000454  Furniture
#
#   Sub-Category                                       Product Name   Sales  \
# 0    Bookcases                  Bush Somerset Collection Bookcase  261.96
# 1       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
#
#    Quantity  Discount    Profit
# 0         2       0.0   41.9136
# 1         3       0.0  219.5820

# %%
data.iloc[[0 , 1] , 2 ] # columns and rows are passsed toghether
# Out:
# 0    CG-12520
# 1    CG-12520
# Name: Customer ID, dtype: object

# %%
data.loc[0] # loc are for label location
# Out:
# Ship Date                       2018-11-11 00:00:00
# Ship Mode                              Second Class
# Customer ID                                CG-12520
# Customer Name                           Claire Gute
# Segment                                    Consumer
# Country/Region                        United States
# City                                      Henderson
# State                                      Kentucky
# Postal Code                                 42420.0
# Region                                        South
# Product ID                          FUR-BO-10001798
# Category                                  Furniture
# Sub-Category                              Bookcases
# Product Name      Bush Somerset Collection Bookcase
# Sales                                        261.96
# Quantity                                          2
# Discount                                        0.0
# Profit                                      41.9136
# Name: 0, dtype: object

# %%
data.loc[[0 , 1]]
# Out:
#    Ship Date     Ship Mode Customer ID Customer Name   Segment Country/Region  \
# 0 2018-11-11  Second Class    CG-12520   Claire Gute  Consumer  United States
# 1 2018-11-11  Second Class    CG-12520   Claire Gute  Consumer  United States
#
#         City     State  Postal Code Region       Product ID   Category  \
# 0  Henderson  Kentucky      42420.0  South  FUR-BO-10001798  Furniture
# 1  Henderson  Kentucky      42420.0  South  FUR-CH-10000454  Furniture
#
#   Sub-Category                                       Product Name   Sales  \
# 0    Bookcases                  Bush Somerset Collection Bookcase  261.96
# 1       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
#
#    Quantity  Discount    Profit
# 0         2       0.0   41.9136
# 1         3       0.0  219.5820

# %%
data.loc[  [0 , 1] , ["Region"  , "Sales"] ]
# Out:
#   Region   Sales
# 0  South  261.96
# 1  South  731.94

# %%
data.loc[0:2 , "Region"]
# Out:
# 0    South
# 1    South
# 2     West
# Name: Region, dtype: object

# %%
data.loc[0:2 , "Region" : "Category"]
# Out:
#   Region       Product ID         Category
# 0  South  FUR-BO-10001798        Furniture
# 1  South  FUR-CH-10000454        Furniture
# 2   West  OFF-LA-10000240  Office Supplies

# %%
data.set_index("Region").head(2)
# Out:
#         Ship Date     Ship Mode Customer ID Customer Name   Segment  \
# Region
# South  2018-11-11  Second Class    CG-12520   Claire Gute  Consumer
# South  2018-11-11  Second Class    CG-12520   Claire Gute  Consumer
#
#        Country/Region       City     State  Postal Code       Product ID  \
# Region
# South   United States  Henderson  Kentucky      42420.0  FUR-BO-10001798
# South   United States  Henderson  Kentucky      42420.0  FUR-CH-10000454
#
#          Category Sub-Category  \
# Region
# South   Furniture    Bookcases
# South   Furniture       Chairs
#
#                                              Product Name   Sales  Quantity  \
# Region
# South                   Bush Somerset Collection Bookcase  261.96         2
# South   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
#
#         Discount    Profit
# Region
# South        0.0   41.9136
# South        0.0  219.5820

# %%
fillt = (data["Region"] == "West")

# %%
data[fillt].head(2)
# Out:
#    Ship Date       Ship Mode Customer ID    Customer Name    Segment  \
# 2 2018-06-16    Second Class    DV-13045  Darrin Van Huff  Corporate
# 5 2016-06-14  Standard Class    BH-11710  Brosina Hoffman   Consumer
#
#   Country/Region         City       State  Postal Code Region  \
# 2  United States  Los Angeles  California      90036.0   West
# 5  United States  Los Angeles  California      90032.0   West
#
#         Product ID         Category Sub-Category  \
# 2  OFF-LA-10000240  Office Supplies       Labels
# 5  FUR-FU-10001487        Furniture  Furnishings
#
#                                         Product Name  Sales  Quantity  \
# 2  Self-Adhesive Address Labels for Typewriters b...  14.62         2
# 5  Eldon Expressions Wood and Plastic Desk Access...  48.86         7
#
#    Discount   Profit
# 2       0.0   6.8714
# 5       0.0  14.1694

# %%
data[data["Region"] == "West"].head(2)
# Out:
#    Ship Date       Ship Mode Customer ID    Customer Name    Segment  \
# 2 2018-06-16    Second Class    DV-13045  Darrin Van Huff  Corporate
# 5 2016-06-14  Standard Class    BH-11710  Brosina Hoffman   Consumer
#
#   Country/Region         City       State  Postal Code Region  \
# 2  United States  Los Angeles  California      90036.0   West
# 5  United States  Los Angeles  California      90032.0   West
#
#         Product ID         Category Sub-Category  \
# 2  OFF-LA-10000240  Office Supplies       Labels
# 5  FUR-FU-10001487        Furniture  Furnishings
#
#                                         Product Name  Sales  Quantity  \
# 2  Self-Adhesive Address Labels for Typewriters b...  14.62         2
# 5  Eldon Expressions Wood and Plastic Desk Access...  48.86         7
#
#    Discount   Profit
# 2       0.0   6.8714
# 5       0.0  14.1694

# %%
fillt_2 = (data["Region"] == "West" ) & ( data["State"] == "California")

# %%
data[fillt_2].head(3)
# Out:
#    Ship Date       Ship Mode Customer ID    Customer Name    Segment  \
# 2 2018-06-16    Second Class    DV-13045  Darrin Van Huff  Corporate
# 5 2016-06-14  Standard Class    BH-11710  Brosina Hoffman   Consumer
# 6 2016-06-14  Standard Class    BH-11710  Brosina Hoffman   Consumer
#
#   Country/Region         City       State  Postal Code Region  \
# 2  United States  Los Angeles  California      90036.0   West
# 5  United States  Los Angeles  California      90032.0   West
# 6  United States  Los Angeles  California      90032.0   West
#
#         Product ID         Category Sub-Category  \
# 2  OFF-LA-10000240  Office Supplies       Labels
# 5  FUR-FU-10001487        Furniture  Furnishings
# 6  OFF-AR-10002833  Office Supplies          Art
#
#                                         Product Name  Sales  Quantity  \
# 2  Self-Adhesive Address Labels for Typewriters b...  14.62         2
# 5  Eldon Expressions Wood and Plastic Desk Access...  48.86         7
# ...

# %%
df = data.drop(['Ship Date', 'Ship Mode',
       'Customer ID', 'Customer Name', 'Segment', 'Country/Region',
       'State', 'Postal Code', 'Product ID', 'Category',
       'Sub-Category', 'Product Name'] , axis = 1)

# %%
df.shape
# Out:
# (9994, 6)

# %%
df.columns
# Out:
# Index(['City', 'Region', 'Sales', 'Quantity', 'Discount', 'Profit'], dtype='object')

# %%
# df.columns = ["columns_1" , "columns_1" , "columns_3" , "df_columns_4"] # changes columns names

# %%
df.head(5)
# Out:
#               City Region     Sales  Quantity  Discount    Profit
# 0        Henderson  South  261.9600         2      0.00   41.9136
# 1        Henderson  South  731.9400         3      0.00  219.5820
# 2      Los Angeles   West   14.6200         2      0.00    6.8714
# 3  Fort Lauderdale  South  957.5775         5      0.45 -383.0310
# 4  Fort Lauderdale  South   22.3680         2      0.20    2.5164

# %%
# df.columns = [x.upper() for x in df.columns]
# df

# %%
# df.columns = df.columns.str.replace(" " , "-")
#df

# %%
df.rename(columns = {"Sales": "Sales_news" , "Quantity" : "Quantity_new"} ) # change the columnnames
# Out:
#                  City Region  Sales_news  Quantity_new  Discount    Profit
# 0           Henderson  South    261.9600             2      0.00   41.9136
# 1           Henderson  South    731.9400             3      0.00  219.5820
# 2         Los Angeles   West     14.6200             2      0.00    6.8714
# 3     Fort Lauderdale  South    957.5775             5      0.45 -383.0310
# 4     Fort Lauderdale  South     22.3680             2      0.20    2.5164
# ...               ...    ...         ...           ...       ...       ...
# 9989            Miami  South     25.2480             3      0.20    4.1028
# 9990       Costa Mesa   West     91.9600             2      0.00   15.6332
# 9991       Costa Mesa   West    258.5760             2      0.20   19.3932
# 9992       Costa Mesa   West     29.6000             4      0.00   13.3200
# 9993      Westminster   West    243.1600             2      0.00   72.9480
#
# [9994 rows x 6 columns]

# %%
df["Region"] = df["Region"].str.replace("West" , "andere")

# %%
 # df["Region"] = df["Region"].str.lower()

# %%
df["Region"] = df["Region"].str.replace("South" , "andere")

# %%
df["Region"].value_counts()
# Out:
# andere     4823
# East       2848
# Central    2323
# Name: Region, dtype: int64

# %%
df["Region"].apply(len)
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 9989    6
# 9990    6
# 9991    6
# 9992    6
# 9993    6
# Name: Region, Length: 9994, dtype: int64

# %%
def update_region(region):
    return region.upper()

# %%
df["Region"].apply(update_region)
# Out:
# 0       ANDERE
# 1       ANDERE
# 2       ANDERE
# 3       ANDERE
# 4       ANDERE
#          ...
# 9989    ANDERE
# 9990    ANDERE
# 9991    ANDERE
# 9992    ANDERE
# 9993    ANDERE
# Name: Region, Length: 9994, dtype: object

# %%
df["Region"] = df["Region"].apply(update_region)
df
# Out:
#                  City  Region     Sales  Quantity  Discount    Profit
# 0           Henderson  ANDERE  261.9600         2      0.00   41.9136
# 1           Henderson  ANDERE  731.9400         3      0.00  219.5820
# 2         Los Angeles  ANDERE   14.6200         2      0.00    6.8714
# 3     Fort Lauderdale  ANDERE  957.5775         5      0.45 -383.0310
# 4     Fort Lauderdale  ANDERE   22.3680         2      0.20    2.5164
# ...               ...     ...       ...       ...       ...       ...
# 9989            Miami  ANDERE   25.2480         3      0.20    4.1028
# 9990       Costa Mesa  ANDERE   91.9600         2      0.00   15.6332
# 9991       Costa Mesa  ANDERE  258.5760         2      0.20   19.3932
# 9992       Costa Mesa  ANDERE   29.6000         4      0.00   13.3200
# 9993      Westminster  ANDERE  243.1600         2      0.00   72.9480
#
# [9994 rows x 6 columns]

# %%
df["New_columns"] = df["Region"].apply(update_region) # add a new columns with the mapping case

# %%
df
# Out:
#                  City  Region     Sales  Quantity  Discount    Profit  \
# 0           Henderson  ANDERE  261.9600         2      0.00   41.9136
# 1           Henderson  ANDERE  731.9400         3      0.00  219.5820
# 2         Los Angeles  ANDERE   14.6200         2      0.00    6.8714
# 3     Fort Lauderdale  ANDERE  957.5775         5      0.45 -383.0310
# 4     Fort Lauderdale  ANDERE   22.3680         2      0.20    2.5164
# ...               ...     ...       ...       ...       ...       ...
# 9989            Miami  ANDERE   25.2480         3      0.20    4.1028
# 9990       Costa Mesa  ANDERE   91.9600         2      0.00   15.6332
# 9991       Costa Mesa  ANDERE  258.5760         2      0.20   19.3932
# 9992       Costa Mesa  ANDERE   29.6000         4      0.00   13.3200
# 9993      Westminster  ANDERE  243.1600         2      0.00   72.9480
#
#      New_columns
# 0         ANDERE
# 1         ANDERE
# 2         ANDERE
# 3         ANDERE
# 4         ANDERE
# ...

# %%
df["Region"] = df["Region"].apply(lambda x : x.lower())
df.head()
# Out:
#               City  Region     Sales  Quantity  Discount    Profit New_columns
# 0        Henderson  andere  261.9600         2      0.00   41.9136      ANDERE
# 1        Henderson  andere  731.9400         3      0.00  219.5820      ANDERE
# 2      Los Angeles  andere   14.6200         2      0.00    6.8714      ANDERE
# 3  Fort Lauderdale  andere  957.5775         5      0.45 -383.0310      ANDERE
# 4  Fort Lauderdale  andere   22.3680         2      0.20    2.5164      ANDERE

# %%
df.apply(len)
# Out:
# City           9994
# Region         9994
# Sales          9994
# Quantity       9994
# Discount       9994
# Profit         9994
# New_columns    9994
# dtype: int64

# %%
df["City"].map({"Henderson" : "berlin" , "Los Angeles" : "München" })
# hier we have a NAN for all value where we do not apply the function map
# Out:
# 0        berlin
# 1        berlin
# 2       München
# 3           NaN
# 4           NaN
#          ...
# 9989        NaN
# 9990        NaN
# 9991        NaN
# 9992        NaN
# 9993        NaN
# Name: City, Length: 9994, dtype: object

# %%
df["City"].replace({"Henderson" : "berlin" , "Los Angeles" : "München" })
# replace ist a better  method to replace a values in a serie
# Out:
# 0                berlin
# 1                berlin
# 2               München
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object

# %%
df["City"] = df["City"].replace({"Henderson" : "berlin" , "Los Angeles" : "München" })

# %%
df["City"].value_counts()
# Out:
# New York City      915
# München            747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
# df.drop(columns = ["City" , "Region"], axis = 1)

# %%
df.sort_values(by = "City" , ascending= False)
# Out:
#           City   Region    Sales  Quantity  Discount    Profit New_columns
# 0       berlin   andere  261.960         2       0.0   41.9136      ANDERE
# 4434    berlin   andere  842.940         3       0.0  160.1586      ANDERE
# 3539    berlin   andere   20.650         5       0.0    9.4990      ANDERE
# 3540    berlin   andere   45.360         7       0.0   21.7728      ANDERE
# 7093    berlin   andere   51.550         5       0.0   24.2285      ANDERE
# ...        ...      ...      ...       ...       ...       ...         ...
# 4324     Akron     east   14.352         3       0.2    0.8970        EAST
# 3560     Akron     east    8.256         4       0.2    0.6192        EAST
# 4092     Akron     east  221.024         2       0.2  -55.2560        EAST
# 6989   Abilene  central    1.392         2       0.8   -3.7584     CENTRAL
# 9260  Aberdeen  central   25.500         3       0.0    6.6300     CENTRAL
#
# [9994 rows x 7 columns]

# %%
df.sort_values(by = ["City" , "Region"] , ascending= False)
# Out:
#           City   Region    Sales  Quantity  Discount    Profit New_columns
# 0       berlin   andere  261.960         2       0.0   41.9136      ANDERE
# 1       berlin   andere  731.940         3       0.0  219.5820      ANDERE
# 538     berlin   andere  152.940         3       0.0   41.2938      ANDERE
# 539     berlin   andere  283.920         4       0.0   70.9800      ANDERE
# 996     berlin   andere   10.670         1       0.0    4.9082      ANDERE
# ...        ...      ...      ...       ...       ...       ...         ...
# 8691     Akron     east  247.188         2       0.4  -49.4376        EAST
# 8692     Akron     east  279.960         5       0.2   48.9930        EAST
# 9921     Akron     east    5.742         3       0.7   -4.5936        EAST
# 6989   Abilene  central    1.392         2       0.8   -3.7584     CENTRAL
# 9260  Aberdeen  central   25.500         3       0.0    6.6300     CENTRAL
#
# [9994 rows x 7 columns]

# %%
df.sort_values(by = ["City" , "Region"] , ascending= [False , True])
# Out:
#           City   Region    Sales  Quantity  Discount    Profit New_columns
# 0       berlin   andere  261.960         2       0.0   41.9136      ANDERE
# 1       berlin   andere  731.940         3       0.0  219.5820      ANDERE
# 538     berlin   andere  152.940         3       0.0   41.2938      ANDERE
# 539     berlin   andere  283.920         4       0.0   70.9800      ANDERE
# 996     berlin   andere   10.670         1       0.0    4.9082      ANDERE
# ...        ...      ...      ...       ...       ...       ...         ...
# 8691     Akron     east  247.188         2       0.4  -49.4376        EAST
# 8692     Akron     east  279.960         5       0.2   48.9930        EAST
# 9921     Akron     east    5.742         3       0.7   -4.5936        EAST
# 6989   Abilene  central    1.392         2       0.8   -3.7584     CENTRAL
# 9260  Aberdeen  central   25.500         3       0.0    6.6300     CENTRAL
#
# [9994 rows x 7 columns]

# %%
df["City"].sort_values()
# Out:
# 9260    Aberdeen
# 6989     Abilene
# 3562       Akron
# 3561       Akron
# 3560       Akron
#           ...
# 7478      berlin
# 7479      berlin
# 2552      berlin
# 4378      berlin
# 0         berlin
# Name: City, Length: 9994, dtype: object

# %%
df["Sales"].nlargest(10)
# Out:
# 2697    22638.480
# 6826    17499.950
# 8153    13999.960
# 2623    11199.968
# 4190    10499.970
# 9039     9892.740
# 4098     9449.950
# 4277     9099.930
# 8488     8749.950
# 6425     8399.976
# Name: Sales, dtype: float64

# %%
df["Sales"].nsmallest(10)
# Out:
# 4101    0.444
# 9292    0.556
# 8658    0.836
# 4711    0.852
# 2106    0.876
# 7548    0.898
# 8033    0.984
# 2761    0.990
# 8024    1.044
# 1332    1.080
# Name: Sales, dtype: float64

# %%
df.nlargest(10 , "Sales")
# Out:
#                City   Region      Sales  Quantity  Discount     Profit  \
# 2697   Jacksonville   andere  22638.480         6       0.5 -1811.0784
# 6826      Lafayette  central  17499.950         5       0.0  8399.9760
# 8153        Seattle   andere  13999.960         4       0.0  6719.9808
# 2623  New York City     east  11199.968         4       0.2  3919.9888
# 4190         Newark     east  10499.970         3       0.0  5039.9856
# 9039        Detroit  central   9892.740        13       0.0  4946.3700
# 4098    Minneapolis  central   9449.950         5       0.0  4630.4755
# 4277       Lakewood     east   9099.930         7       0.0  2365.9818
# 8488      Arlington   andere   8749.950         5       0.0  2799.9840
# 6425   Philadelphia     east   8399.976         4       0.4  1119.9968
#
#      New_columns
# 2697      ANDERE
# 6826     CENTRAL
# 8153      ANDERE
# 2623        EAST
# 4190        EAST
# 9039     CENTRAL
# 4098     CENTRAL
# 4277        EAST
# 8488      ANDERE
# ...

# %%
df.nsmallest(10 , "Sales")
# Out:
#                City   Region  Sales  Quantity  Discount  Profit New_columns
# 4101        Houston  central  0.444         1       0.8 -1.1100     CENTRAL
# 9292           Waco  central  0.556         1       0.8 -0.9452     CENTRAL
# 8658        Chicago  central  0.836         1       0.8 -1.3376     CENTRAL
# 4711   Philadelphia     east  0.852         1       0.7 -0.5964        EAST
# 2106       Mesquite  central  0.876         1       0.8 -1.4016     CENTRAL
# 7548     Huntsville  central  0.898         1       0.8 -1.5715     CENTRAL
# 8033        Houston  central  0.984         2       0.8 -1.4760     CENTRAL
# 2761  San Francisco   andere  0.990         1       0.0  0.4356      ANDERE
# 8024         Dallas  central  1.044         1       0.8 -1.8270     CENTRAL
# 1332         Dallas  central  1.080         3       0.8 -1.7280     CENTRAL

# %% [markdown]
# ## aggregation

# %%
df["Sales"].median()
# Out:
# 54.489999999999995

# %%
df["Sales"].mean()
# Out:
# 229.8580008304938

# %%
df.median() # but be carefull not all result are meanigfull
# Out:
# C:\Users\boris-thibaut.tondju\AppData\Local\Temp\ipykernel_13056\386685638.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median() # but be carefull not all result are meanigfull
# Sales       54.4900
# Quantity     3.0000
# Discount     0.2000
# Profit       8.6665
# dtype: float64

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
df["Sales"].value_counts()
# Out:
# 12.960     56
# 19.440     39
# 15.552     39
# 10.368     36
# 32.400     28
#            ..
# 825.174     1
# 569.536     1
# 796.425     1
# 12.832      1
# 243.160     1
# Name: Sales, Length: 6144, dtype: int64

# %%
df["Sales"].value_counts(normalize=True) # to in percentage
# Out:
# 12.960     0.005603
# 19.440     0.003902
# 15.552     0.003902
# 10.368     0.003602
# 32.400     0.002802
#              ...
# 825.174    0.000100
# 569.536    0.000100
# 796.425    0.000100
# 12.832     0.000100
# 243.160    0.000100
# Name: Sales, Length: 6144, dtype: float64

# %%
df.groupby(["City"])

# %%
# je me suis arreter au video des missing daza donc je vais ontinuer labs

# %%
# use an optional parameter to the describe method to summarize only 'object' columns
df.describe(include=['object'])
# Out:
#                  City  Region New_columns
# count            9994    9994        9994
# unique            531       3           3
# top     New York City  andere      ANDERE
# freq              915    4823        4823

# %%
# replace all spaces with underscores in the column names by using the 'str.replace' method
# df.columns = df.columns.str.replace(' ', '_')
# df.columns

# %%
df.head()
# Out:
#               City  Region     Sales  Quantity  Discount    Profit New_columns
# 0           berlin  andere  261.9600         2      0.00   41.9136      ANDERE
# 1           berlin  andere  731.9400         3      0.00  219.5820      ANDERE
# 2          München  andere   14.6200         2      0.00    6.8714      ANDERE
# 3  Fort Lauderdale  andere  957.5775         5      0.45 -383.0310      ANDERE
# 4  Fort Lauderdale  andere   22.3680         2      0.20    2.5164      ANDERE

# %%
#liste = []
#for col in df["Quantity"]:
#    if df["Quantity"] == 2:
#        liste.append(True)
#    else:
#        liste.append(False)

# %%
# various methods are available to iterate through a DataFrame
for index, row in df.iterrows():
    print(index, row.City, row.Quantity)
# Out:
# 0 berlin 2
# 1 berlin 3
# 2 München 2
# 3 Fort Lauderdale 5
# 4 Fort Lauderdale 2
# 5 München 7
# 6 München 4
# 7 München 6
# 8 München 3
# 9 München 5
# 10 München 9
# 11 München 4
# 12 Concord 3
# 13 Seattle 3
# 14 Fort Worth 5
# 15 Fort Worth 3
# 16 Madison 6
# 17 West Jordan 2
# 18 San Francisco 2
# 19 San Francisco 3
# 20 San Francisco 4
# 21 Fremont 7
# 22 Fremont 7
# 23 Philadelphia 2
# 24 Orem 3
# 25 München 2
# 26 München 3
# 27 Philadelphia 7
# 28 Philadelphia 2
# 29 Philadelphia 3
# 30 Philadelphia 2
# 31 Philadelphia 6
# 32 Philadelphia 6
# 33 Philadelphia 2
# 34 Houston 3
# 35 Richardson 7
# 36 Richardson 5
# 37 Houston 9
# 38 Houston 3
# 39 Houston 3
# 40 Houston 4
# 41 Naperville 4
# 42 München 2
# 43 Melbourne 2
# 44 Eagan 2
# 45 Eagan 2
# 46 Westland 4
# 47 Dover 3
# 48 Dover 2
# 49 New Albany 6
# 50 New Albany 6
# 51 New Albany 2
# 52 New Albany 1
# 53 New York City 7
# 54 New York City 5
# 55 Troy 6
# 56 Troy 5
# 57 Troy 5
# 58 Troy 2
# 59 Troy 2
# 60 Troy 4
# ...

# %%
# only include numeric columns in the DataFrame
df.select_dtypes(include=[np.number]).dtypes
# Out:
# Sales       float64
# Quantity      int64
# Discount    float64
# Profit      float64
# dtype: object

# %%
# pass the string 'all' to describe all columns
df.describe(include='all')
# Out:
#                  City  Region         Sales     Quantity     Discount  \
# count            9994    9994   9994.000000  9994.000000  9994.000000
# unique            531       3           NaN          NaN          NaN
# top     New York City  andere           NaN          NaN          NaN
# freq              915    4823           NaN          NaN          NaN
# mean              NaN     NaN    229.858001     3.789574     0.156203
# std               NaN     NaN    623.245101     2.225110     0.206452
# min               NaN     NaN      0.444000     1.000000     0.000000
# 25%               NaN     NaN     17.280000     2.000000     0.000000
# 50%               NaN     NaN     54.490000     3.000000     0.200000
# 75%               NaN     NaN    209.940000     5.000000     0.200000
# max               NaN     NaN  22638.480000    14.000000     0.800000
#
#              Profit New_columns
# count   9994.000000        9994
# unique          NaN           3
# ...

# %%
# count the non-null values, unique values, and frequency of the most common value
df.Region.describe()
# Out:
# count       9994
# unique         3
# top       andere
# freq        4823
# Name: Region, dtype: object

# %%
df["City"].describe()
# Out:
# count              9994
# unique              531
# top       New York City
# freq                915
# Name: City, dtype: object

# %%
df["City"].value_counts()
# Out:
# New York City      915
# München            747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
# row 0, all columns
df.loc[0, :]
# Out:
# City            berlin
# Region          andere
# Sales           261.96
# Quantity             2
# Discount           0.0
# Profit         41.9136
# New_columns     ANDERE
# Name: 0, dtype: object

# %%
type(df_umpy)
# Out:
# NoneType

# %%
df_numpy = df.to_numpy()
# convert a dataframe to a numy array

# %%
df_numpy
# Out:
# array([['berlin', 'andere', 261.96, ..., 0.0, 41.9136, 'ANDERE'],
#        ['berlin', 'andere', 731.9399999999999, ..., 0.0,
#         219.58199999999997, 'ANDERE'],
#        ['München', 'andere', 14.62, ..., 0.0, 6.8713999999999995,
#         'ANDERE'],
#        ...,
#        ['Costa Mesa', 'andere', 258.576, ..., 0.2, 19.393200000000007,
#         'ANDERE'],
#        ['Costa Mesa', 'andere', 29.6, ..., 0.0, 13.32, 'ANDERE'],
#        ['Westminster', 'andere', 243.16, ..., 0.0, 72.94799999999998,
#         'ANDERE']], dtype=object)

# %%
type(df_numpy)
# Out:
# numpy.ndarray

# %%
for row in df.iterrows():
        for col in range(2, 4):
            df.set_value('row', 'col', 3)
