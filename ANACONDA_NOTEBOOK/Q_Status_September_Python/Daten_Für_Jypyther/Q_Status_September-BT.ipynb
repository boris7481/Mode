# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("220928_MGU18_BT_Q-Status_September_Daten.xlsx")

# %%
pd.set_option('display.max_row', 147)
pd.set_option('display.max_column', 147)

# %%
df.head()
# Out:
#           ID FAHRGESTELLNR_7 PRODUKTIONSDATUM_MONATSGENAU  \
# 0  609466114         FM69570                      2022-03
# 1  609493198         9L92622                      2022-03
# 2  609512632         CK38848                      2022-03
# 3  609525990         9L67746                      2022-03
# 4  609530999         FM69758                      2022-03
#
#   GUTSCHRIFTSDATUM_MONATSGENAU BAUREIHE_FZG_KLASSEN PRODUKTIONSDATUM  \
# 0                      2022-03                  G26       02.03.2022
# 1                      2022-04                  G05       24.03.2022
# 2                      2022-04                  F90       23.03.2022
# 3                      2022-04                  G05       04.03.2022
# 4                      2022-04                  G21       02.03.2022
#
#   ZULASSUNGSDATUM REPARATURDATUM  \
# 0      19.03.2022     22.03.2022
# 1      30.03.2022     07.04.2022
# 2      08.04.2022     11.04.2022
# 3      06.04.2022     19.04.2022
# 4      29.03.2022     05.04.2022
#
#                                 BEFUND06_AND_BEZ  \
# 0        651256 HEADUNIT BASIS (OHNE NAVIGATION)
# 1  651258 HEADUNIT HIGH HU-H (NAVI PROFESSIONAL)
# 2               841126 BLUETOOTH TELEFONFUNKTION
# 3  651258 HEADUNIT HIGH HU-H (NAVI PROFESSIONAL)
# 4  651258 HEADUNIT HIGH HU-H (NAVI PROFESSIONAL)
#
#                                 KOMMENTARSAMMLUNG_GW      PQM_NR  \
# 0  BLUETOOTH NOT WORKING, CARRIED OUT HEAD UNIT R...    kein PQM
# 1  B 65 07 21CLIENT STATES THAT THE VEHICLES BLUE...    kein PQM
# 2                         Keine Kommentare vorhanden    kein PQM
# 3  Tried to connect phone to vehicle but screen g...    kein PQM
# 4  Apple Carplay und Zusatztelefon ausgef. Fz neu...  1156647649
#
#   FEHLERTYP_CLUSTER                                  ROOTCAUSE_CLUSTER  \
# 0  Nicht zuzuordnen                        unzureichende Informationen
# 1  Nicht zuzuordnen                         Endgeräte: Bluetooth issue
# 2  Nicht zuzuordnen                        unzureichende Informationen
# 3  Nicht zuzuordnen                        unzureichende Informationen
# 4          Software  MGU: Unterversorgung HL Firma Cypress BBT/WiFi...
#
#                   TECH_PROBLEMBILD_CLUSTER VERURSACHER_CLUSTER  \
# 0  Bluetooth: Funktionsstörung/Performance    Nicht zuzuordnen
# 1   Bluetooth: Verbindungsabbruch/Probleme    Nicht zuzuordnen
# 2  Bluetooth: Funktionsstörung/Performance    Nicht zuzuordnen
# 3                Bluetooth: Device Pairing    Nicht zuzuordnen
# 4              Apple Car Play: No Function         Entwicklung
#
#                            PROBLEMBESCHREIBUNG_KUNDE  \
# 0                              BLUETOOTH NOT WORKING
# 1  CLIENT STATES THAT THE VEHICLES BLUETOOTH CONN...
# 2                                                NaN
# 3  Tried to connect phone to vehicle but screen g...
# 4  Apple Carplay und Zusatztelefon ausgef. Fz neu...
#
#                        PROBLEMBESCHREIBUNG_TECHNISCH LAENDERAUSFUEHRUNG  \
# 0                    Funktion nach Reset der HU i.O.                EUR
# 1                                  GOOGLE Pixel 3 XL                USA
# 2  6P1 Austattung , ohne Kunden BA nicht zurorden...                EUR
# 3  Apple Inc.<separator>iPhone12,8\t\nApple Inc.<...                EUR
# 4      S-06P1\tTemp. Entfall Remote Software Upgrade                EUR
#
#   ORDERLAND TEILETAUSCH_GENERELL RELEVANTER_FEHLERSPEICHER I_STUFE_VOR_REP  \
# 0        GB                    N                     keine  S18A-22-03-520
# 1        US                    N                     keine  S18A-21-11-564
# 2        DE                    N                     keine  S15A-22-03-520
# 3        GB                    N                     keine  S18A-21-11-560
# 4        CH                    N                     keine  S18A-22-03-520
#
#    MnP_GWK  MnP_REAL  MODELL_REF PRODUKTLINIE1 REPARATURLAND  \
# 0        1         0         NaN            LK            GB
# 1        2         0         NaN            LG            US
# 2        2         0         NaN            ZS            DE
# 3        2         1         NaN            LG            GB
# 4        2         1         NaN            LK            CH
#
#    HAENDLERNUMMER_REPARATUR REPARATURDATUM_MONATSGENAU F2_DATUM_MONATSGENAU  \
# 0                     10055                    2022-03              2022-03
# 1                     51008                    2022-04              2022-03
# 2                     23532                    2022-04              2022-03
# 3                      8708                    2022-04              2022-03
# 4                      7020                    2022-04              2022-03
#
#                               VFC_Bez   BEMERKUNG     ISTUFE_WERK  \
# 0  Headunit Basis / Headunit Mid kpl.  MGU Alpine  S18A-22-03-520
# 1                       Headunit High  MGU Harman  S18A-21-11-564
# 2             Telefon / Bluetooth SG.  MGU HARMAN  S15A-22-03-520
# 3                       Headunit High  MGU HARMAN  S18A-21-11-560
# 4                       Headunit High  MGU HARMAN  S18A-22-03-520
#
#   BEARBEITUNGS_STATUS                                 HAENDLER_REPARATUR  \
# 0       Abgeschlossen  Sytner Harold WoodA12 Colchester Road  Romford...
# 1       Abgeschlossen  South Shore BMW1040 Hingham Street  Rockland  ...
# 2       Abgeschlossen  Autohaus Hoyer GmbHKräher Weg 33  Nienburg  31...
# 3       Abgeschlossen  Inchcape ChelmsfordColchester Road  Chelmsford...
# 4       Abgeschlossen  R. Bühler AGAustrasse 8  Neuenegg  3176  BESch...
#
#   BIT_ANDERER_VERURSACHER GW_KULANZSTUFE ANDERER_VERURSACHER_CLUSTER  \
# 0                    nein            1-3                   undefined
# 1                      ja            1-3             EXT - Endgeräte
# 2                    nein            1-3                   undefined
# 3                    nein            1-3                   undefined
# 4                    nein            1-3                   undefined
#
#   GUTSCHRIFTSDATUM_WOCHENGENAU   FAHRGESTELLNR_17            TPK Modul  \
# 0                      2022-12  WBA12AW080FM69570  E - 03 - CoCo    CD
# 1                      2022-14  5UXCR6C03N9L92622  E - 03 - CoCo    CD
# 2                      2022-15  WBS81CH020CK38848  E - 03 - CoCo    CD
# 3                      2022-16  WBATH420609L67746  E - 03 - CoCo    CD
# 4                      2022-16  WBA51DZ020FM69758  E - 03 - CoCo    CD
#
#   AG_GWK_FALLKOSTEN      BefCluster Modul_lang FEHLERTYP_CLUSTER.1  \
# 0             73,43   CD - Headunit       CD02    Nicht zuzuordnen
# 1            141,57   CD - Headunit       CD02    Nicht zuzuordnen
# 2             81,76  CD - Telefonie       CD02    Nicht zuzuordnen
# 3             93,90   CD - Headunit       CD02    Nicht zuzuordnen
# 4            127,21   CD - Headunit       CD02            Software
#
#                                  ROOTCAUSE_CLUSTER.1  \
# 0                        unzureichende Informationen
# 1                         Endgeräte: Bluetooth issue
# 2                        unzureichende Informationen
# 3                        unzureichende Informationen
# 4  MGU: Unterversorgung HL Firma Cypress BBT/WiFi...
#
#                 TECH_PROBLEMBILD_CLUSTER.1 VERURSACHER_CLUSTER.1  \
# 0  Bluetooth: Funktionsstörung/Performance      Nicht zuzuordnen
# 1   Bluetooth: Verbindungsabbruch/Probleme      Nicht zuzuordnen
# 2  Bluetooth: Funktionsstörung/Performance      Nicht zuzuordnen
# 3                Bluetooth: Device Pairing      Nicht zuzuordnen
# 4              Apple Car Play: No Function           Entwicklung
#
#                          PROBLEMBESCHREIBUNG_KUNDE.1  \
# 0                              BLUETOOTH NOT WORKING
# 1  CLIENT STATES THAT THE VEHICLES BLUETOOTH CONN...
# 2                                                NaN
# 3  Tried to connect phone to vehicle but screen g...
# 4  Apple Carplay und Zusatztelefon ausgef. Fz neu...
#
#                      PROBLEMBESCHREIBUNG_TECHNISCH.1 LAENDERAUSFUEHRUNG.1  \
# 0                    Funktion nach Reset der HU i.O.                  EUR
# 1                                  GOOGLE Pixel 3 XL                  USA
# 2  6P1 Austattung , ohne Kunden BA nicht zurorden...                  EUR
# 3  Apple Inc.<separator>iPhone12,8\t\nApple Inc.<...                  EUR
# 4      S-06P1\tTemp. Entfall Remote Software Upgrade                  EUR
#
#   ORDERLAND.1 TEILETAUSCH_GENERELL.1 RELEVANTER_FEHLERSPEICHER.1  \
# 0          GB                      N                       keine
# 1          US                      N                       keine
# 2          DE                      N                       keine
# 3          GB                      N                       keine
# 4          CH                      N                       keine
#
#   I_STUFE_VOR_REP.1  MnP_GWK.1  MnP_REAL.1  MODELL_REF.1 PRODUKTLINIE1.1  \
# 0    S18A-22-03-520          1           0           NaN              LK
# 1    S18A-21-11-564          2           0           NaN              LG
# 2    S15A-22-03-520          2           0           NaN              ZS
# 3    S18A-21-11-560          2           1           NaN              LG
# 4    S18A-22-03-520          2           1           NaN              LK
#
#   REPARATURLAND.1  HAENDLERNUMMER_REPARATUR.1 REPARATURDATUM_MONATSGENAU.1  \
# 0              GB                       10055                      2022-03
# 1              US                       51008                      2022-04
# 2              DE                       23532                      2022-04
# 3              GB                        8708                      2022-04
# 4              CH                        7020                      2022-04
#
#   F2_DATUM_MONATSGENAU.1                           VFC_Bez.1 BEMERKUNG.1  \
# 0                2022-03  Headunit Basis / Headunit Mid kpl.  MGU Alpine
# 1                2022-03                       Headunit High  MGU Harman
# 2                2022-03             Telefon / Bluetooth SG.  MGU HARMAN
# 3                2022-03                       Headunit High  MGU HARMAN
# 4                2022-03                       Headunit High  MGU HARMAN
#
#     ISTUFE_WERK.1 BEARBEITUNGS_STATUS.1  \
# 0  S18A-22-03-520         Abgeschlossen
# 1  S18A-21-11-564         Abgeschlossen
# 2  S15A-22-03-520         Abgeschlossen
# 3  S18A-21-11-560         Abgeschlossen
# 4  S18A-22-03-520         Abgeschlossen
#
#                                 HAENDLER_REPARATUR.1  \
# 0  Sytner Harold WoodA12 Colchester Road  Romford...
# 1  South Shore BMW1040 Hingham Street  Rockland  ...
# 2  Autohaus Hoyer GmbHKräher Weg 33  Nienburg  31...
# 3  Inchcape ChelmsfordColchester Road  Chelmsford...
# 4  R. Bühler AGAustrasse 8  Neuenegg  3176  BESch...
#
#   BIT_ANDERER_VERURSACHER.1 GW_KULANZSTUFE.1 ANDERER_VERURSACHER_CLUSTER.1  \
# 0                      nein              1-3                     undefined
# 1                        ja              1-3               EXT - Endgeräte
# 2                      nein              1-3                     undefined
# 3                      nein              1-3                     undefined
# 4                      nein              1-3                     undefined
#
#   GUTSCHRIFTSDATUM_WOCHENGENAU.1 FAHRGESTELLNR_17.1          TPK.1 Modul.1  \
# 0                        2022-12  WBA12AW080FM69570  E - 03 - CoCo      CD
# 1                        2022-14  5UXCR6C03N9L92622  E - 03 - CoCo      CD
# 2                        2022-15  WBS81CH020CK38848  E - 03 - CoCo      CD
# 3                        2022-16  WBATH420609L67746  E - 03 - CoCo      CD
# 4                        2022-16  WBA51DZ020FM69758  E - 03 - CoCo      CD
#
#   AG_GWK_FALLKOSTEN.1    BefCluster.1 Modul_lang.1
# 0               73,43   CD - Headunit         CD02
# 1              141,57   CD - Headunit         CD02
# 2               81,76  CD - Telefonie         CD02
# 3               93,90   CD - Headunit         CD02
# 4              127,21   CD - Headunit         CD02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 79 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               149 non-null    int64
#  1   FAHRGESTELLNR_7                  149 non-null    object
#  2   PRODUKTIONSDATUM_MONATSGENAU     149 non-null    object
#  3   GUTSCHRIFTSDATUM_MONATSGENAU     149 non-null    object
#  4   BAUREIHE_FZG_KLASSEN             149 non-null    object
#  5   PRODUKTIONSDATUM                 149 non-null    object
#  6   ZULASSUNGSDATUM                  149 non-null    object
#  7   REPARATURDATUM                   149 non-null    object
#  8   BEFUND06_AND_BEZ                 149 non-null    object
#  9   KOMMENTARSAMMLUNG_GW             149 non-null    object
#  10  PQM_NR                           149 non-null    object
#  11  FEHLERTYP_CLUSTER                149 non-null    object
#  12  ROOTCAUSE_CLUSTER                149 non-null    object
#  13  TECH_PROBLEMBILD_CLUSTER         149 non-null    object
#  14  VERURSACHER_CLUSTER              149 non-null    object
#  15  PROBLEMBESCHREIBUNG_KUNDE        139 non-null    object
#  16  PROBLEMBESCHREIBUNG_TECHNISCH    109 non-null    object
#  17  LAENDERAUSFUEHRUNG               149 non-null    object
#  18  ORDERLAND                        149 non-null    object
#  19  TEILETAUSCH_GENERELL             149 non-null    object
#  20  RELEVANTER_FEHLERSPEICHER        122 non-null    object
#  21  I_STUFE_VOR_REP                  140 non-null    object
#  22  MnP_GWK                          149 non-null    int64
#  23  MnP_REAL                         149 non-null    int64
#  24  MODELL_REF                       0 non-null      float64
#  25  PRODUKTLINIE1                    149 non-null    object
#  26  REPARATURLAND                    149 non-null    object
#  27  HAENDLERNUMMER_REPARATUR         149 non-null    int64
#  28  REPARATURDATUM_MONATSGENAU       149 non-null    object
#  29  F2_DATUM_MONATSGENAU             149 non-null    object
#  30  VFC_Bez                          149 non-null    object
#  31  BEMERKUNG                        147 non-null    object
#  32  ISTUFE_WERK                      149 non-null    object
#  33  BEARBEITUNGS_STATUS              149 non-null    object
#  34  HAENDLER_REPARATUR               149 non-null    object
#  35  BIT_ANDERER_VERURSACHER          149 non-null    object
#  36  GW_KULANZSTUFE                   149 non-null    object
#  37  ANDERER_VERURSACHER_CLUSTER      149 non-null    object
#  38  GUTSCHRIFTSDATUM_WOCHENGENAU     149 non-null    object
#  39  FAHRGESTELLNR_17                 149 non-null    object
#  40  TPK                              149 non-null    object
#  41  Modul                            149 non-null    object
#  42  AG_GWK_FALLKOSTEN                149 non-null    object
#  43  BefCluster                       149 non-null    object
#  44  Modul_lang                       149 non-null    object
#  45  FEHLERTYP_CLUSTER.1              149 non-null    object
#  46  ROOTCAUSE_CLUSTER.1              149 non-null    object
#  47  TECH_PROBLEMBILD_CLUSTER.1       149 non-null    object
#  48  VERURSACHER_CLUSTER.1            149 non-null    object
#  49  PROBLEMBESCHREIBUNG_KUNDE.1      139 non-null    object
#  50  PROBLEMBESCHREIBUNG_TECHNISCH.1  109 non-null    object
#  51  LAENDERAUSFUEHRUNG.1             149 non-null    object
#  52  ORDERLAND.1                      149 non-null    object
#  53  TEILETAUSCH_GENERELL.1           149 non-null    object
#  54  RELEVANTER_FEHLERSPEICHER.1      122 non-null    object
#  55  I_STUFE_VOR_REP.1                140 non-null    object
#  56  MnP_GWK.1                        149 non-null    int64
#  57  MnP_REAL.1                       149 non-null    int64
#  58  MODELL_REF.1                     0 non-null      float64
#  59  PRODUKTLINIE1.1                  149 non-null    object
#  60  REPARATURLAND.1                  149 non-null    object
#  61  HAENDLERNUMMER_REPARATUR.1       149 non-null    int64
#  62  REPARATURDATUM_MONATSGENAU.1     149 non-null    object
#  63  F2_DATUM_MONATSGENAU.1           149 non-null    object
#  64  VFC_Bez.1                        149 non-null    object
#  65  BEMERKUNG.1                      147 non-null    object
#  66  ISTUFE_WERK.1                    149 non-null    object
#  67  BEARBEITUNGS_STATUS.1            149 non-null    object
#  68  HAENDLER_REPARATUR.1             149 non-null    object
#  69  BIT_ANDERER_VERURSACHER.1        149 non-null    object
#  70  GW_KULANZSTUFE.1                 149 non-null    object
#  71  ANDERER_VERURSACHER_CLUSTER.1    149 non-null    object
#  72  GUTSCHRIFTSDATUM_WOCHENGENAU.1   149 non-null    object
#  73  FAHRGESTELLNR_17.1               149 non-null    object
#  74  TPK.1                            149 non-null    object
#  75  Modul.1                          149 non-null    object
#  76  AG_GWK_FALLKOSTEN.1              149 non-null    object
#  77  BefCluster.1                     149 non-null    object
#  78  Modul_lang.1                     149 non-null    object
# dtypes: float64(2), int64(7), object(70)
# memory usage: 92.1+ KB

# %%
df.shape
# Out:
# (149, 79)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isna(), cbar=False)
# Out:
# <AxesSubplot:>
